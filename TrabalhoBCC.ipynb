# %% [markdown]
# <a href="https://colab.research.google.com/github/juliatosato/Python_works/blob/main/TrabalhoBCC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**TRABALHO DE BASES COMPUTACIONAIS DA CIÊNCIA**
# ###ANÁLISE DA DADOS SOBRE RENDA FAMILIAR E RELAÇÃO DE DESPESAS FAMILIARES MENSAIS COM A INSEGURANÇA ALIMENTAR
# ####Julia Tosato de Jesus

# %%
#importação de todas as bibliotecas que usaremos
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#leitura e nomeação de todas as tabelas a serem usadas

# %% [markdown]
# #TABELA ***1A*** DESPESAS TOTAIS BRASIL EM 2017-2018

# %%
#Despesa monetária e não monetária média mensal familiar, por situação de segurança alimentar existente no domicílio, segundo os tipos de despesa - Brasil - período 2017-2018
#essa tabela Brasil considera a média de todas as regiões em que a pesquisa foi feita, e daremos enfoque nos dados da região urbana e rural a seguir

# %%
tab1total = pd.read_csv('https://docs.google.com/uc?export=download&id=1ltSc4K1HrNQv8J7qgkMB6rMRDWfRgknT ', encoding = 'latin1', sep = ';') #código para ler a tabela no link export=download com algumas alterações para que o programa pudesse ler a tabela corretamente (fizemos essa codificação com ajuda de sites e vídeos no youtube)
tab1total.head(53) #impressão da tabela apenas com as linhas que têm conteúdo a ser utilizado para melhor consulta da tabela

#repetimos esse mesmo processo em todas as tabelas utilizadas
#em todas as tabelas existem colunas com as siglas 'CSA' e 'CIA', que se referam a famílias 'com segurança alimentar' e 'com insegurança alimentar', respectivamente
# Out:
#                               Tipos de despesa  \
# 0                                Despesa total
# 1                           Despesas correntes
# 2                          Despesas de consumo
# 3                                  Alimentação
# 4                                    Habitação
# 5                                      Aluguel
# 6                            Aluguel monetário
# 7                        Aluguel não monetário
# 8                                   Condomínio
# 9                             Serviços e taxas
# 10                            Energia elétrica
# 11                               Telefone fixo
# 12                            Telefone Celular
# 13           Pacote de telefone, TV e Internet
# 14                               Gás doméstico
# 15                               Água e esgoto
# 16                                      Outros
# 17                           Manutenção do lar
# 18                          Artigos de limpeza
# ...

# %% [markdown]
# #TABELA ***1B*** DESPESAS TOTAIS RURAL EM 2017-2018

# %%
#Despesa monetária e não monetária média mensal familiar, por situação de segurança alimentar existente no domicílio, segundo os tipos de despesa - Rural - período 2017-2018

# %%
tab1rural = pd.read_csv('https://docs.google.com/uc?export=download&id=19GPogBrxmGaWuaaOfcfXMAfbrB5nKJqw', encoding = 'latin1', sep = ';')  #código para ler a tabela no link export=download com algumas alterações para que o programa pudesse ler a tabela corretamente
tab1rural.head(53)  #impressão da tabela apenas com as linhas que têm conteúdo a ser utilizado para melhor consulta da tabela
# Out:
#                               Tipos de despesa  \
# 0                                Despesa total
# 1                           Despesas correntes
# 2                          Despesas de consumo
# 3                                  Alimentação
# 4                                    Habitação
# 5                                      Aluguel
# 6                            Aluguel monetário
# 7                        Aluguel não monetário
# 8                                   Condomínio
# 9                             Serviços e taxas
# 10                            Energia elétrica
# 11                               Telefone fixo
# 12                            Telefone Celular
# 13           Pacote de telefone, TV e Internet
# 14                               Gás doméstico
# 15                               Água e esgoto
# 16                                      Outros
# 17                           Manutenção do lar
# 18                          Artigos de limpeza
# ...

# %% [markdown]
# #TABELA ***1C*** DESPESAS TOTAIS URBANA EM 2017-2018

# %%
#Despesa monetária e não monetária média mensal familiar, por situação de segurança alimentar existente no domicílio, segundo os tipos de despesa - Urbana - período 2017-2018

# %%
tab1urbana = pd.read_csv('https://docs.google.com/uc?export=download&id=1DwpPdCOIThTdMhMCaxWlAWK_mLWUiChq', encoding = 'latin1', sep = ';')  #código para ler a tabela no link export=download com algumas alterações para que o programa pudesse ler a tabela corretamente
tab1urbana.head(53)  #impressão da tabela apenas com as linhas que têm conteúdo a ser utilizado para melhor consulta da tabela
# Out:
#                               Tipos de despesa  \
# 0                                Despesa total
# 1                           Despesas correntes
# 2                          Despesas de consumo
# 3                                  Alimentação
# 4                                    Habitação
# 5                                      Aluguel
# 6                            Aluguel monetário
# 7                        Aluguel não monetário
# 8                                   Condomínio
# 9                             Serviços e taxas
# 10                            Energia elétrica
# 11                               Telefone fixo
# 12                            Telefone Celular
# 13           Pacote de telefone, TV e Internet
# 14                               Gás doméstico
# 15                               Água e esgoto
# 16                                      Outros
# 17                           Manutenção do lar
# 18                          Artigos de limpeza
# ...

# %% [markdown]
# #TABELA ***2*** RENDIMENTO FAMILIAR TOTAL BRASIL EM 2017-2018

# %%
#Despesa monetária e não monetária média mensal familiar, por situação de segurança alimentar existente no domicílio, segundo os tipos de despesa - Brasil - período 2017-2018

# %%
tab2rendfambrasil = pd.read_csv('https://docs.google.com/uc?export=download&id=1zedNLfIjfERchyBQfhMXS7uZfDOMFhjQ', encoding = 'latin1', sep = ';')  #código para ler a tabela no link export=download com algumas alterações para que o programa pudesse ler a tabela corretamente
tab2rendfambrasil.head(20)  #impressão da tabela apenas com as linhas que têm conteúdo a ser utilizado para melhor consulta da tabela
# Out:
#                               Origem dos recebimentos      Total        CSA  \
# 0                                                 NaN        NaN        NaN
# 1             Rendimento total e variação patrimonial   5 433.34   6 732.51
# 2                                                 NaN        NaN        NaN
# 3                                   Rendimento total    5 094.75   6 283.04
# 4                                                 NaN        NaN        NaN
# 5                              Rendimento do trabalho   3 121.81   3 925.09
# 6                                           Empregado   2 156.24   2 656.23
# 7                                          Empregador     365.67     543.31
# 8                                       Conta própria     599.90     725.55
# 9                                       Transferência   1 058.14   1 298.39
# 10                     Aposentadoria e pensão do INSS     583.80     702.99
# ...

# %% [markdown]
# #GRÁFICOS

# %% [markdown]
# ###Tabela *A*: Despesas com Alimentação - Brasil

# %%
#gráfico de despesa monetária e não monetária média mensal familiar, por situação de segurança alimentar existente no domicílio - ALIMENTAÇÃO
tab1total.loc[(3)] #isolamento da linha de dados alimentação, da tabela A, para fazer a coluna total
# Out:
# Tipos de despesa                                                                       Alimentação
# Total                                                                                       658.79
# CSA                                                                                         730.57
# Leve CIA                                                                                    576.68
# Moderada CIA                                                                                475.72
# Grave CIA                                                                                   420.96
# Unnamed: 6                                                                                     NaN
# Name: 3, dtype: object

# %%
tab1urbana.loc[(3)] #isolamento da linha de dados alimentação, da tabela A, para fazer a coluna urbana
# Out:
# Tipos de despesa                                                                       Alimentação
# Total                                                                                       681.79
# CSA                                                                                         755.92
# Leve CIA                                                                                    587.28
# Moderada CIA                                                                                480.03
# Grave CIA                                                                                   422.53
# Unnamed: 6                                                                                     NaN
# Name: 3, dtype: object

# %%
tab1rural.loc[(3)] #isolamento da linha de dados alimentação, da tabela A, para fazer a coluna rural
# Out:
# Tipos de despesa                                                                       Alimentação
# Total                                                                                       515.05
# CSA                                                                                         538.82
# Leve CIA                                                                                    519.33
# Moderada CIA                                                                                459.11
# Grave CIA                                                                                   415.25
# Unnamed: 6                                                                                     NaN
# Name: 3, dtype: object

# %%
x = np.arange(4)  #estabelecimento de variáveis x para montagem do gráfico
y1 = [730.57, 576.68, 475.72, 420.96]  #todos valores de dados totais
y2 = [755.92, 587.28, 480.03, 422.53]  #todos valores de dados urbanos
y3 = [538.82, 519.33, 459.11, 415.25]  #todos valores de dados rurais
width = 0.2  #largura das barras
plt.bar(x-0.2, y1, width, color='mediumvioletred')  #estabelecimento da barra de total com valores das variáveis, largura e cor
plt.bar(x, y2, width, color='deeppink')  #estabelecimento da barra de urbano com valores das variáveis, largura e cor
plt.bar(x+0.2, y3, width, color='hotpink')  #estabelecimento da barra de rural com valores das variáveis, largura e cor
plt.xticks(x, ['CSA', 'Leve CIA', 'Moderada CIA', 'Grave CIA'])  #nomeação das variáveis do eixo x
plt.xlabel("Condição")  #título do eixo x
plt.ylabel("Gasto Mensal")  #título do eixo y
plt.title("ALIMENTAÇÃO")  #título do gráfico
plt.legend(["Geral", "Urbano", "Rural"])  #legenda do gráfico
plt.show()  #plotagem para gerar o gráfico

# %% [markdown]
# ###Tabela *B*: Despesas com Habitação - Brasil

# %%
#gráfico de despesa monetária e não monetária média mensal familiar, por situação de segurança alimentar existente no domicílio - HABITAÇÃO
tab1total.loc[(4)] #isolamento da linha de dados habitação, da tabela A, para fazer a coluna total
# Out:
# Tipos de despesa                                                                       Habitação
# Total                                                                                   1 378.90
# CSA                                                                                     1 640.08
# Leve CIA                                                                                1 017.60
# Moderada CIA                                                                              800.04
# Grave CIA                                                                                 687.76
# Unnamed: 6                                                                                   NaN
# Name: 4, dtype: object

# %%
tab1urbana.loc[(4)] #isolamento da linha de dados habitação, da tabela A, para fazer a coluna urbana
# Out:
# Tipos de despesa                                                                       Habitação
# Total                                                                                   1 492.84
# CSA                                                                                     1 751.52
# Leve CIA                                                                                1 101.07
# Moderada CIA                                                                              889.18
# Grave CIA                                                                                 758.15
# Unnamed: 6                                                                                   NaN
# Name: 4, dtype: object

# %%
tab1rural.loc[(4)] #isolamento da linha de dados habitação, da tabela A, para fazer a coluna rural
# Out:
# Tipos de despesa                                                                       Habitação
# Total                                                                                     666.95
# CSA                                                                                       796.98
# Leve CIA                                                                                  566.19
# Moderada CIA                                                                              457.01
# Grave CIA                                                                                 431.53
# Unnamed: 6                                                                                   NaN
# Name: 4, dtype: object

# %%
x = np.arange(4)  #estabelecimento de variáveis x para montagem do gráfico
y1 = [1640.08, 1017.60, 800.04, 687.76]  #todos valores de dados totais
y2 = [1751.52, 1101.07, 889.18, 758.15]  #todos valores de dados urbanos
y3 = [796.98, 566.19, 457.01, 431.53]  #todos valores de dados rurais
width = 0.2  #largura das barras
plt.bar(x-0.2, y1, width, color='royalblue')  #estabelecimento da barra de total com valores das variáveis, largura e cor
plt.bar(x, y2, width, color='cornflowerblue')  #estabelecimento da barra de urbano com valores das variáveis, largura e cor
plt.bar(x+0.2, y3, width, color='skyblue')  #estabelecimento da barra de rural com valores das variáveis, largura e cor
plt.xticks(x, ['CSA', 'Leve CIA', 'Moderada CIA', 'Grave CIA'])  #nomeação das variáveis do eixo x
plt.xlabel("Condição")  #título do eixo x
plt.ylabel("Gasto Mensal")  #título do eixo y
plt.title("HABITAÇÃO")  #título do gráfico
plt.legend(["Geral", "Urbano", "Rural"])  #legenda do gráfico
plt.show()  #plotagem para gerar o gráfico

# %% [markdown]
# ###Tabela *C*: Despesas com Energia Elétrica - Brasil

# %%
#gráfico de despesa monetária e não monetária média mensal familiar, por situação de segurança alimentar existente no domicílio - ENERGIA ELÉTRICA
tab1total.loc[(10)] #isolamento da linha de dados energia elétrica, da tabela A, para fazer a coluna total
# Out:
# Tipos de despesa                                                                         Energia elétrica
# Total                                                                                              115.45
# CSA                                                                                                127.66
# Leve CIA                                                                                           102.27
# Moderada CIA                                                                                        84.58
# Grave CIA                                                                                           70.37
# Unnamed: 6                                                                                            NaN
# Name: 10, dtype: object

# %%
tab1urbana.loc[(10)] #isolamento da linha de dados energia elétrica, da tabela A, para fazer a coluna urbana
# Out:
# Tipos de despesa                                                                         Energia elétrica
# Total                                                                                              123.08
# CSA                                                                                                133.70
# Leve CIA                                                                                           110.66
# Moderada CIA                                                                                        94.48
# Grave CIA                                                                                           79.15
# Unnamed: 6                                                                                            NaN
# Name: 10, dtype: object

# %%
tab1rural.loc[(10)] #isolamento da linha de dados energia elétrica, da tabela A, para fazer a coluna rural
# Out:
# Tipos de despesa                                                                         Energia elétrica
# Total                                                                                               67.74
# CSA                                                                                                 81.97
# Leve CIA                                                                                            56.89
# Moderada CIA                                                                                        46.48
# Grave CIA                                                                                           38.40
# Unnamed: 6                                                                                            NaN
# Name: 10, dtype: object

# %%
x = np.arange(4)  #estabelecimento de variáveis x para montagem do gráfico
y1 = [127.66, 102.27, 84.58, 70.37]  #todos valores de dados totais
y2 = [133.70, 110.66, 94.48, 79.15]  #todos valores de dados urbanos
y3 = [81.97, 56.89, 46.48, 38.40]  #todos valores de dados rurais
width = 0.2  #largura das barras
plt.bar(x-0.2, y1, width, color='darkgreen')  #estabelecimento da barra de total com valores das variáveis, largura e cor
plt.bar(x, y2, width, color='forestgreen')  #estabelecimento da barra de urbano com valores das variáveis, largura e cor
plt.bar(x+0.2, y3, width, color='limegreen')  #estabelecimento da barra de rural com valores das variáveis, largura e cor
plt.xticks(x, ['CSA', 'Leve CIA', 'Moderada CIA', 'Grave CIA'])  #nomeação das variáveis do eixo x
plt.xlabel("Condição")  #título do eixo x
plt.ylabel("Gasto Mensal")  #título do eixo y
plt.title("ENERGIA ELÉTRICA")  #título do gráfico
plt.legend(["Geral", "Urbano", "Rural"])  #legenda do gráfico
plt.show()  #plotagem para gerar o gráfico

# %% [markdown]
# ###Tabela *D*: Despesas com Telefone, TV e Internet - Brasil

# %%
#gráfico de despesa monetária e não monetária média mensal familiar, por situação de segurança alimentar existente no domicílio - TELEFONE, TV E INTERNET
tab1total.loc[(13)] #isolamento da linha de dados telefone, tv e internet, da tabela A, para fazer a coluna total
# Out:
# Tipos de despesa                                                                         Pacote de telefone, TV e Internet
# Total                                                                                                                50.47
# CSA                                                                                                                  64.79
# Leve CIA                                                                                                             31.17
# Moderada CIA                                                                                                         17.68
# Grave CIA                                                                                                            11.82
# Unnamed: 6                                                                                                             NaN
# Name: 13, dtype: object

# %%
tab1urbana.loc[(13)] #isolamento da linha de dados telefone, tv e internet, da tabela A, para fazer a coluna urbana
# Out:
# Tipos de despesa                                                                         Pacote de telefone, TV e Internet
# Total                                                                                                                57.65
# CSA                                                                                                                  72.27
# Leve CIA                                                                                                             36.29
# Moderada CIA                                                                                                         21.86
# Grave CIA                                                                                                            14.67
# Unnamed: 6                                                                                                             NaN
# Name: 13, dtype: object

# %%
tab1rural.loc[(13)] #isolamento da linha de dados telefone, tv e internet, da tabela A, para fazer a coluna rural
# Out:
# Tipos de despesa                                                                         Pacote de telefone, TV e Internet
# Total                                                                                                                 5.62
# CSA                                                                                                                   8.18
# Leve CIA                                                                                                              3.47
# Moderada CIA                                                                                                          1.60
# Grave CIA                                                                                                             1.43
# Unnamed: 6                                                                                                             NaN
# Name: 13, dtype: object

# %%
x = np.arange(4)  #estabelecimento de variáveis x para montagem do gráfico
y1 = [64.79, 31.17, 17.68, 11.82]  #todos valores de dados totais
y2 = [72.27, 36.29, 21.86, 14.67]  #todos valores de dados urbanos
y3 = [8.18, 3.47, 1.60, 1.43]  #todos valores de dados rurais
width = 0.2  #largura das barras
plt.bar(x-0.2, y1, width, color='darkred')  #estabelecimento da barra de total com valores das variáveis, largura e cor
plt.bar(x, y2, width, color='firebrick')  #estabelecimento da barra de urbano com valores das variáveis, largura e cor
plt.bar(x+0.2, y3, width, color='red')  #estabelecimento da barra de rural com valores das variáveis, largura e cor
plt.xticks(x, ['CSA', 'Leve CIA', 'Moderada CIA', 'Grave CIA'])  #nomeação das variáveis do eixo x
plt.xlabel("Condição")  #título do eixo x
plt.ylabel("Gasto Mensal")  #título do eixo y
plt.title("TELEFONE, TV E INTERNET")  #título do gráfico
plt.legend(["Geral", "Urbano", "Rural"])  #legenda do gráfico
plt.show()  #plotagem para gerar o gráfico

# %% [markdown]
# ###Tabela *E*: Despesas com Higiene e Cuidados - Brasil

# %%
#gráfico de despesa monetária e não monetária média mensal familiar, por situação de segurança alimentar existente no domicílio - HIGIENE E CUIDADOS
tab1total.loc[(37)] #isolamento da linha de dados higiene e cuidados, da tabela A, para fazer a coluna total
# Out:
# Tipos de despesa                                                                       Higiene e Cuidados Pessoais
# Total                                                                                                       136.88
# CSA                                                                                                         146.07
# Leve CIA                                                                                                    131.63
# Moderada CIA                                                                                                107.80
# Grave CIA                                                                                                    88.81
# Unnamed: 6                                                                                                     NaN
# Name: 37, dtype: object

# %%
tab1urbana.loc[(37)] #isolamento da linha de dados higiene e cuidados, da tabela A, para fazer a coluna urbana
# Out:
# Tipos de despesa                                                                       Higiene e Cuidados Pessoais
# Total                                                                                                       143.07
# CSA                                                                                                         151.78
# Leve CIA                                                                                                    137.17
# Moderada CIA                                                                                                113.96
# Grave CIA                                                                                                    92.88
# Unnamed: 6                                                                                                     NaN
# Name: 37, dtype: object

# %%
tab1rural.loc[(37)] #isolamento da linha de dados higiene e cuidados, da tabela A, para fazer a coluna rural
# Out:
# Tipos de despesa                                                                       Higiene e Cuidados Pessoais
# Total                                                                                                        98.22
# CSA                                                                                                         102.89
# Leve CIA                                                                                                    101.67
# Moderada CIA                                                                                                 84.09
# Grave CIA                                                                                                    73.98
# Unnamed: 6                                                                                                     NaN
# Name: 37, dtype: object

# %%
x = np.arange(4)  #estabelecimento de variáveis x para montagem do gráfico
y1 = [146.07, 131.63, 107.80, 88.81]  #todos valores de dados totais
y2 = [151.78, 137.17, 113.96, 92.88]  #todos valores de dados urbanos
y3 = [102.89, 101.67, 84.09, 73.98]  #todos valores de dados rurais
width = 0.2  #largura das barras
plt.bar(x-0.2, y1, width, color='orangered')  #estabelecimento da barra de total com valores das variáveis, largura e cor
plt.bar(x, y2, width, color='darkorange')  #estabelecimento da barra de urbano com valores das variáveis, largura e cor
plt.bar(x+0.2, y3, width, color='orange')  #estabelecimento da barra de rural com valores das variáveis, largura e cor
plt.xticks(x, ['CSA', 'Leve CIA', 'Moderada CIA', 'Grave CIA'])  #nomeação das variáveis do eixo x
plt.xlabel("Condição")  #título do eixo x
plt.ylabel("Gasto Mensal")  #título do eixo y
plt.title("HIGIENE E CUIDADOS")  #título do gráfico
plt.legend(["Geral", "Urbano", "Rural"])  #legenda do gráfico
plt.show()  #plotagem para gerar o gráfico

# %% [markdown]
# ###Tabela *F*: Despesas com Seguro/Plano Saúde - Brasil

# %%
#gráfico de despesa monetária e não monetária média mensal familiar, por situação de segurança alimentar existente no domicílio - SEGURO/PLANO SAÚDE
tab1total.loc[(44)] #isolamento da linha de dados seguro/plano saúde, da tabela A, para fazer a coluna total
# Out:
# Tipos de despesa                                                                        Plano/Seguro saúde
# Total                                                                                                95.57
# CSA                                                                                                 130.54
# Leve CIA                                                                                             44.67
# Moderada CIA                                                                                         19.84
# Grave CIA                                                                                            13.31
# Unnamed: 6                                                                                             NaN
# Name: 44, dtype: object

# %%
tab1urbana.loc[(44)] #isolamento da linha de dados seguro/plano saúde, da tabela A, para fazer a coluna urbana
# Out:
# Tipos de despesa                                                                        Plano/Seguro saúde
# Total                                                                                               108.80
# CSA                                                                                                 145.00
# Leve CIA                                                                                             51.94
# Moderada CIA                                                                                         24.79
# Grave CIA                                                                                            16.74
# Unnamed: 6                                                                                             NaN
# Name: 44, dtype: object

# %%
tab1rural.loc[(44)] #isolamento da linha de dados seguro/plano saúde, da tabela A, para fazer a coluna rural
# Out:
# Tipos de despesa                                                                        Plano/Seguro saúde
# Total                                                                                                12.92
# CSA                                                                                                  21.10
# Leve CIA                                                                                              5.38
# Moderada CIA                                                                                          0.80
# Grave CIA                                                                                             0.81
# Unnamed: 6                                                                                             NaN
# Name: 44, dtype: object

# %%
x = np.arange(4)  #estabelecimento de variáveis x para montagem do gráfico
y1 = [130.54, 44.67, 19.84, 13.31]  #todos valores de dados totais
y2 = [145.00, 51.94, 24.79, 16.74]  #todos valores de dados urbanos
y3 = [21.10, 5.38, 0.80, 0.81]  #todos valores de dados rurais
width = 0.2  #largura das barras
plt.bar(x-0.2, y1, width, color='purple') #estabelecimento da barra de total com valores das variáveis, largura e cor
plt.bar(x, y2, width, color='darkviolet')  #estabelecimento da barra de urbano com valores das variáveis, largura e cor
plt.bar(x+0.2, y3, width, color='mediumorchid')  #estabelecimento da barra de rural com valores das variáveis, largura e cor
plt.xticks(x, ['CSA', 'Leve CIA', 'Moderada CIA', 'Grave CIA'])  #nomeação das variáveis do eixo x
plt.xlabel("Condição") #título do eixo x
plt.ylabel("Gasto Mensal")  #título do eixo y
plt.title("PLANO/SEGURO SAÚDE")  #título do gráfico
plt.legend(["Geral", "Urbano", "Rural"])  #legenda do gráfico
plt.show()  #plotagem para gerar o gráfico

# %% [markdown]
# ###Tabela *G*: Rendimento Familiar Total - Brasil

# %%
#gráfico de rendimento familiar total, por situação de segurança alimentar existente no domicílio
tab2rendfambrasil.loc[(3)] #isolamento da linha de dados seguro/plano saúde, da tabela A, para fazer a coluna total
# Out:
# Origem dos recebimentos    Rendimento total
# Total                               5 094.75
# CSA                                 6 283.04
# Leve CIA                            3 432.79
# Moderada CIA                        2 441.95
# Grave CIA                           2 080.68
# Name: 3, dtype: object

# %%
condicao = ['CSA', 'Leve CIA', 'Moderada CIA', 'Grave CIA']  #estabelecimento de valores para o eixo x
rendtotal = [6283.04, 3432.79, 2441.95, 2080.68]  #estabelecimento de valores para o eixo y
plt.barh(condicao, rendtotal, color='teal')  #código para plotagem do gráfico de barras horizontais
plt.ylabel("Condição")  #título do eixo y
plt.xlabel("Rendimento em R$")  #título do eixo x
plt.title("Rendimento Familiar Total Mensal")  #título do gráfico
plt.show()  #impressão do gráfico

# %% [markdown]
# # **OBRIGADA**
